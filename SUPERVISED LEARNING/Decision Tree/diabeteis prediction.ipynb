# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

# %%
dataset=load_diabetes()

# %%
dataset
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
print(dataset["DESCR"])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
df_dataset=pd.DataFrame(dataset.data,columns=["age","sex","bmi","bp","s1","s2","s3","s4","s5","s6"])

# %%
df_dataset
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
X=df_dataset

Y=dataset["target"]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=40)

# %%
x_train.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.141301  0.234150  0.332892  0.285592  0.260704 -0.095826
# sex  0.141301  1.000000  0.103081  0.217275  0.002696  0.124169 -0.383618
# bmi  0.234150  0.103081  1.000000  0.484194  0.263851  0.281320 -0.331715
# bp   0.332892  0.217275  0.484194  1.000000  0.272348  0.216771 -0.171849
# s1   0.285592  0.002696  0.263851  0.272348  1.000000  0.898255  0.099838
# s2   0.260704  0.124169  0.281320  0.216771  0.898255  1.000000 -0.174089
# s3  -0.095826 -0.383618 -0.331715 -0.171849  0.099838 -0.174089  1.000000
# s4   0.241654  0.336603  0.391250  0.275347  0.514499  0.670592 -0.732113
# s5   0.282784  0.128841  0.426544  0.420387  0.507038  0.317096 -0.344825
# s6   0.323534  0.263595  0.373092  0.478257  0.319552  0.305478 -0.249945
#
#            s4        s5        s6
# age  0.241654  0.282784  0.323534
# sex  0.336603  0.128841  0.263595
# bmi  0.391250  0.426544  0.373092
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(x_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeRegressor

treeregressor=DecisionTreeRegressor()

treeregressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# # HYPERPARAMATER TUNING

# %%
params={

    "criterion" :["squared_error", "friedman_mse", "absolute_error", "poisson"],
    "splitter" :["best", "random"],
    "max_depth" :[1,2,3,4,5,10,15,20,25],   
    "max_features" :["auto","sqrt","log2"]  
}

# %%
params
# Out:
# {'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
#  'splitter': ['best', 'random'],
#  'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#  'max_features': ['auto', 'sqrt', 'log2']}

# %%
from sklearn.model_selection import GridSearchCV

treemodel=DecisionTreeRegressor()

grid=GridSearchCV(treemodel,cv=5,param_grid=params,scoring="neg_mean_squared_error")



import warnings
warnings.filterwarnings("ignore")
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
predict=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

mse=mean_squared_error(y_test,predict)
print(mse)

mae=mean_absolute_error(y_test,predict)
print(mae)

r2=r2_score(y_test,predict)
print(r2*100)
# Out:
# 4340.473476916004
# 51.2953564628674
# 29.60339552278146

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 2,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
grid.best_score_
# Out:
# np.float64(-3482.416543929687)

# %% [markdown]
# # visualize decision tree

# %%
model=DecisionTreeRegressor(criterion = "poisson",max_depth= 2,max_features= 'log2',splitter= 'random')

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_depth=2, max_features='log2',
#                       splitter='random')

# %%
plt.Figure(figsize=(15,10))
from sklearn import tree

tree.plot_tree(model,filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[6] <= -0.007\npoisson = 19.609\nsamples = 309\nvalue = 147.602'),
#  Text(0.25, 0.5, 'x[6] <= -0.018\npoisson = 16.795\nsamples = 142\nvalue = 175.106'),
#  Text(0.375, 0.6666666666666667, 'True  '),
#  Text(0.125, 0.16666666666666666, 'poisson = 15.8\nsamples = 111\nvalue = 184.658'),
#  Text(0.375, 0.16666666666666666, 'poisson = 15.861\nsamples = 31\nvalue = 140.903'),
#  Text(0.75, 0.5, 'x[3] <= 0.059\npoisson = 17.987\nsamples = 167\nvalue = 124.216'),
#  Text(0.625, 0.6666666666666667, '  False'),
#  Text(0.625, 0.16666666666666666, 'poisson = 15.444\nsamples = 150\nvalue = 116.08'),
#  Text(0.875, 0.16666666666666666, 'poisson = 20.41\nsamples = 17\nvalue = 196.0')]
